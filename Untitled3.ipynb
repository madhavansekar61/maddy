# %%
import pandas as pd

# %%
import numpy as np

# %%
data={
    'name':['maddy','axsh','dhanush','sandeep'],
    'age':[20,np.nan,20,np.nan],
    'city':['ariyalur','bangalore','tirutani','ambur'],
    'gender':['male','female','male','male'],
    'qualification':['np.nan','b.tech','np.nan','b.tech'],
    'salry':[25000,30000,250000,10000]
}

# %%
df = pd.DataFrame(data)

# %%
df.isnull().sum()
# Out:
# name             0
# age              2
# city             0
# gender           0
# qualification    0
# salry            0
# dtype: int64

# %%
df.dropna(axis=1)
# Out:
#       name       city  gender qualification   salry
# 0    maddy   ariyalur    male        np.nan   25000
# 1     axsh  bangalore  female        b.tech   30000
# 2  dhanush   tirutani    male        np.nan  250000
# 3  sandeep      ambur    male        b.tech   10000

# %%
df.fillna(value='Filling Value')
# Out:
#       name            age       city  gender qualification   salry
# 0    maddy           20.0   ariyalur    male        np.nan   25000
# 1     axsh  Filling Value  bangalore  female        b.tech   30000
# 2  dhanush           20.0   tirutani    male        np.nan  250000
# 3  sandeep  Filling Value      ambur    male        b.tech   10000

# %%
df
# Out:
#       name   age       city  gender qualification   salry
# 0    maddy  20.0   ariyalur    male        np.nan   25000
# 1     axsh   NaN  bangalore  female        b.tech   30000
# 2  dhanush  20.0   tirutani    male        np.nan  250000
# 3  sandeep   NaN      ambur    male        b.tech   10000

# %%
a=df['age'].fillna(value=df['age'].mean())

# %%
df
# Out:
#       name   age       city  gender qualification   salry
# 0    maddy  20.0   ariyalur    male        np.nan   25000
# 1     axsh   NaN  bangalore  female        b.tech   30000
# 2  dhanush  20.0   tirutani    male        np.nan  250000
# 3  sandeep   NaN      ambur    male        b.tech   10000

# %%
a
# Out:
# 0    20.0
# 1    20.0
# 2    20.0
# 3    20.0
# Name: age, dtype: float64

# %%
df
# Out:
#       name   age       city  gender qualification   salry
# 0    maddy  20.0   ariyalur    male        np.nan   25000
# 1     axsh   NaN  bangalore  female        b.tech   30000
# 2  dhanush  20.0   tirutani    male        np.nan  250000
# 3  sandeep   NaN      ambur    male        b.tech   10000

# %%
df.mean(numeric_only=True)
# Out:
# age         20.0
# salry    78750.0
# dtype: float64

# %%
df['salry'].std()
# Out:
# 114482.53141855312

# %%
df.groupby('city').count()
# Out:
#            name  age  gender  qualification  salry
# city
# ambur         1    0       1              1      1
# ariyalur      1    1       1              1      1
# bangalore     1    0       1              1      1
# tirutani      1    1       1              1      1

# %%
df.groupby('city').describe()
# Out:
#             age                                         salry                \
#           count  mean std   min   25%   50%   75%   max count      mean std
# city
# ambur       0.0   NaN NaN   NaN   NaN   NaN   NaN   NaN   1.0   10000.0 NaN
# ariyalur    1.0  20.0 NaN  20.0  20.0  20.0  20.0  20.0   1.0   25000.0 NaN
# bangalore   0.0   NaN NaN   NaN   NaN   NaN   NaN   NaN   1.0   30000.0 NaN
# tirutani    1.0  20.0 NaN  20.0  20.0  20.0  20.0  20.0   1.0  250000.0 NaN
#
#
#                 min       25%       50%       75%       max
# city
# ambur       10000.0   10000.0   10000.0   10000.0   10000.0
# ariyalur    25000.0   25000.0   25000.0   25000.0   25000.0
# bangalore   30000.0   30000.0   30000.0   30000.0   30000.0
# tirutani   250000.0  250000.0  250000.0  250000.0  250000.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1   3  13  18
# 2  12  12   9
# 3  18  11  18
# 4   3  17   6

# %%
df2
# Out:
#     W   X   Y
# 5  38  27  39
# 6  24  39  27
# 7  27  33  39
# 8  39  30  30

# %%
df3
# Out:
#      W   X   Y
# 9   42  42  54
# 10  57  42  57
# 11  50  44  53
# 12  53  42  45

# %%
frame=[df1,f2,df3]

# %%
pd.concat(frame)
# Out:
#      W   X   Y
# 1    3  13  18
# 2   12  12   9
# 3   18  11  18
# 4    3  17   6
# 5   23  24  26
# 6   33  38  27
# 7   28  34  36
# 8   35  32  35
# 9   42  42  54
# 10  57  42  57
# 11  50  44  53
# 12  53  42  45

# %%
pd.concat(frame,axis=1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1    3.0  13.0  18.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   12.0  12.0   9.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   18.0  11.0  18.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.0  17.0   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  23.0  24.0  26.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  33.0  38.0  27.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  28.0  34.0  36.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  35.0  32.0  35.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  42.0  42.0  54.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  57.0  42.0  57.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  50.0  44.0  53.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  53.0  42.0  45.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left = pd.DataFrame(left)

# %%
right=pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
pd.merge
# Out:
# <function pandas.core.reshape.merge.merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'>

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}

# %%
left = pd.DataFrame(left, index = ['k0','k1','k2'])

# %%
right = pd.DataFrame(right, index = ['k0','k1','k2'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k1  C2  D2
# k2  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k1  A1  B1  C2  D2
# k2  A2  B2  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k1  A1  B1  C2  D2
# k2  A2  B2  C3  D3

# %%
left.join
# Out:
# <bound method DataFrame.join of      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2>

# %%
df=pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
###readingfiles###

# %%
df=pd.read_excel("/content/aug_train.xlsx")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['']
