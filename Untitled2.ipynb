# %%
import pandas as pd
data={
    'name':['maddy','axsh','dhanush','sandeep'],
    'age':[20,19,20,22],
    'city':['ariyalur','bangalore','tirutani','ambur'],
    'gender':['male','female','male','male'],
    'qualification':['b.tech','b.tech','b.tech','b.tech'],
    'salry':[25000,30000,250000,10000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city  gender qualification   salry
# 0    maddy   20   ariyalur    male        b.tech   25000
# 1     axsh   19  bangalore  female        b.tech   30000
# 2  dhanush   20   tirutani    male        b.tech  250000
# 3  sandeep   22      ambur    male        b.tech   10000

# %%
df.shape
# Out:
# (4, 6)

# %%
df.size
# Out:
# 24

# %%
df.tail(3)
# Out:
#       name  age       city  gender qualification   salry
# 1     axsh   19  bangalore  female        b.tech   30000
# 2  dhanush   20   tirutani    male        b.tech  250000
# 3  sandeep   22      ambur    male        b.tech   10000

# %%
df.head(2)
# Out:
#     name  age       city  gender qualification  salry
# 0  maddy   20   ariyalur    male        b.tech  25000
# 1   axsh   19  bangalore  female        b.tech  30000

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'gender', 'qualification', 'salry'], dtype='object')

# %%
df.columns.values
# Out:
# array(['name', 'age', 'city', 'gender', 'qualification', 'salry'],
#       dtype=object)

# %%
df.columns[1]
# Out:
# 'age'

# %%
data= pd.read_csv("/content/archive.zip")

# %%
data
# Out:
#         roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 0        std-01    male        group D                some college    1.0
# 1        std-02    male        group B                 high school    1.0
# 2        std-03    male        group C             master's degree    1.0
# 3        std-04    male        group D                some college    1.0
# 4        std-05    male        group C                some college    0.0
# ...         ...     ...            ...                         ...    ...
# 9995   std-9996  female        group C                some college    1.0
# 9996   std-9997  female        group C           bachelor's degree    1.0
# 9997   std-9998  female        group B          associate's degree    1.0
# 9998   std-9999  female        group B            some high school    1.0
# 9999  std-10000  female        group B                 high school    1.0
#
#       test_preparation_course math_score  reading_score  writing_score  \
# ...

# %%
data.head(20)
# Out:
#    roll_no gender race_ethnicity parental_level_of_education  lunch  \
# 0   std-01   male        group D                some college    1.0
# 1   std-02   male        group B                 high school    1.0
# 2   std-03   male        group C             master's degree    1.0
# 3   std-04   male        group D                some college    1.0
# 4   std-05   male        group C                some college    0.0
# 5   std-06   male        group B                 high school    1.0
# 6   std-07    NaN        group C                some college    0.0
# 7   std-08   male        group B          associate's degree    1.0
# 8   std-09   male        group C                         NaN    1.0
# 9   std-10   male        group C            some high school    NaN
# 10  std-11   male        group C                 high school    1.0
# 11  std-12   male        group E          associate's degree    1.0
# 12  std-13   male        group A          associate's degree    1.0
# ...

# %%
data.tail(999)
# Out:
#         roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 9001   std-9002  female        group C            some high school    1.0
# 9002   std-9003  female        group D                some college    1.0
# 9003   std-9004  female        group C                 high school    1.0
# 9004   std-9005  female        group C           bachelor's degree    1.0
# 9005   std-9006  female        group B                some college    0.0
# ...         ...     ...            ...                         ...    ...
# 9995   std-9996  female        group C                some college    1.0
# 9996   std-9997  female        group C           bachelor's degree    1.0
# 9997   std-9998  female        group B          associate's degree    1.0
# 9998   std-9999  female        group B            some high school    1.0
# 9999  std-10000  female        group B                 high school    1.0
#
#       test_preparation_course math_score  reading_score  writing_score  \
# ...

# %%
data.columns.values
# Out:
# array(['roll_no', 'gender', 'race_ethnicity',
#        'parental_level_of_education', 'lunch', 'test_preparation_course',
#        'math_score', 'reading_score', 'writing_score', 'science_score',
#        'total_score', 'grade'], dtype=object)

# %%
data.columns
# Out:
# Index(['roll_no', 'gender', 'race_ethnicity', 'parental_level_of_education',
#        'lunch', 'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'science_score', 'total_score', 'grade'],
#       dtype='object')

# %%
data.columns[11]
# Out:
# 'grade'

# %%
data.shape
# Out:
# (10000, 12)

# %%
data.size
# Out:
# 120000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   roll_no                      9999 non-null   object
#  1   gender                       9982 non-null   object
#  2   race_ethnicity               9977 non-null   object
#  3   parental_level_of_education  9978 non-null   object
#  4   lunch                        9976 non-null   float64
#  5   test_preparation_course      9977 non-null   float64
#  6   math_score                   9976 non-null   object
#  7   reading_score                9975 non-null   float64
#  8   writing_score                9976 non-null   float64
#  9   science_score                9977 non-null   float64
#  10  total_score                  9981 non-null   float64
#  11  grade                        9997 non-null   object
# dtypes: float64(6), object(6)
# ...

# %%
data.describe()
# Out:
#              lunch  test_preparation_course  reading_score  writing_score  \
# count  9976.000000              9977.000000    9975.000000    9976.000000
# mean      0.644246                 0.388694      70.125915      71.415798
# std       0.478765                 0.487478      19.026245      18.245360
# min       0.000000                 0.000000      17.000000      10.000000
# 25%       0.000000                 0.000000      57.000000      59.000000
# 50%       1.000000                 0.000000      71.000000      72.500000
# 75%       1.000000                 1.000000      85.000000      85.000000
# max       1.000000                 1.000000     100.000000     100.000000
#
#        science_score  total_score
# count    9977.000000  9981.000000
# mean       66.063045   264.740908
# std        19.324331    42.304858
# min         9.000000    89.000000
# 25%        53.000000   237.000000
# 50%        67.000000   268.000000
# 75%        81.000000   294.000000
# ...

# %%
data.isnull().sum()
# Out:
# roll_no                         1
# gender                         18
# race_ethnicity                 23
# parental_level_of_education    22
# lunch                          24
# test_preparation_course        23
# math_score                     24
# reading_score                  25
# writing_score                  24
# science_score                  23
# total_score                    19
# grade                           3
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# roll_no                        0
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# science_score                  0
# total_score                    0
# grade                          0
# dtype: int64
